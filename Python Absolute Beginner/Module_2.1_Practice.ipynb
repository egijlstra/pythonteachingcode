# %% [markdown]
# # Module 2 Practice
# ## Functions Arguments & Parameters
# <font size="5" color="#00A0B2"  face="verdana"> <B>Student will be able to</B></font>
# - **create functions with a parameter**
# - **create functions with a `return` value**
# - **create functions with multiple parameters**
# - **use knowledge of sequence in coding tasks**
# - **use coding best practices**

# %% [markdown]
# ## &nbsp;
# <font size="6" color="#B24C00"  face="verdana"> <B>Tasks</B></font>

# %%
# [ ] define and call a function short_rhyme() that prints a 2 line rhyme
def short_rhyme():
    print('chewing gum is really gross')
    print('chewing gum I hate the most')

short_rhyme()
# Out:
# chewing gum is really gross
# chewing gum I hate the most

# %%
# [ ] define (def) a simple function: title_it() and call the function
# - has a string parameter: msg
# - prints msg in Title Case
def title_it(msg):
    print(msg.title())

title_it('the wind in the willows')
# Out:
# The Wind In The Willows

# %%
# [ ] get user input with prompt "what is the title?" 
# [ ] call title_it() using input for the string argument
title_name = input('what is the title?')

title_it(title_name)
# Out:
# what is the title? harry potter
# Harry Potter

# %%
# [ ] define title_it_rtn() which returns a titled string instead of printing
# [ ] call title_it_rtn() using input for the string argumetnt and print the result
def title_it_rtn(title):
    title_str = title.title()
    return title_str

title_in = input("what's the title?")

print(title_it_rtn(title_in))
# Out:
# what's the title? harry potter
# Harry Potter

# %% [markdown]
# ## Program: bookstore()
# create and test bookstore()
# - **bookstore() takes 2 string arguments: book & price**
# - **bookstore returns a string in sentence form**
# - **bookstore() should call title_it_rtn()** with book parameter
# - **gather input for book_entry and price_entry to use in calling bookstore()**
# - **print the return value of bookstore()**
# >example of output: **`Title: The Adventures Of Sherlock Holmes, costs $12.99`**

# %%
# [ ] create, call and test bookstore() function
def bookstore(book, price):
    book_info = 'Title: ' + title_it_rtn(book) + ', costs ' + price
    return book_info

book_entry = input('what is the name of the book?')
price_entry = input('what is the price of the book?')

book_sum = bookstore(book_entry, price_entry)
print(book_sum)
# Out:
# what is the name of the book? harry potter
# what is the price of the book? 12.99
# Title: Harry Potter, costs 12.99

# %% [markdown]
# ### Fix the error

# %%
def make_greeting(name, greeting = "Hello"):
    return (greeting + " " + name + "!")

# get name and greeting, send to make_greeting 

def get_name():
    name_entry = input("enter a name: ")
    return name_entry

def get_greeting():
    greeting_entry = input("enter a greeting: ")
    return greeting_entry

print(make_greeting(get_name(), get_greeting()))
# Out:
# enter a name:  Erik
# enter a greeting:  Hello
# Hello Erik!

# %% [markdown]
# [Terms of use](http://go.microsoft.com/fwlink/?LinkID=206977) &nbsp; [Privacy & cookies](https://go.microsoft.com/fwlink/?LinkId=521839) &nbsp; © 2017 Microsoft
